# %%
import pandas as pd
import numpy as np

# %%
autos =  pd.read_csv('autos.csv', encoding='latin1')

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos = autos.rename(columns={'yearOfRegistration':'registration_year','monthOfRegistration':'registration_month',
'notRepairedDamage':'unrepaired_damage','dateCreated':'ad_created', 'nrOfPictures':'num_photos','dateCrawled':'date_crawled',
                              'dateCreated':'ad_created',
                              'lastSeen':'last_seen'})

# %% [markdown]
# For future manipulations and comfortable work with the dataframe, we renamed the necessary columns in the snake case style.

# %%
autos.select_dtypes(include=['object', 'category']).describe()
# Out:
#                date_crawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-03-19 17:36:18  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
#
#        vehicleType  gearbox  model   odometer fuelType       brand  \
# count        44905    47320  47242      50000    45518       50000
# unique           8        2    245         13        7          40
# top      limousine  manuell   golf  150,000km   benzin  volkswagen
# freq         12859    36993   4024      32424    30107       10687
#
#        unrepaired_damage           ad_created            last_seen
# count              40171                50000                50000
# unique                 2                   76                39481
# ...

# %%
autos.select_dtypes(include=['number']).describe()
# Out:
#        registration_year       powerPS  registration_month  num_photos  \
# count       50000.000000  50000.000000        50000.000000     50000.0
# mean         2005.073280    116.355920            5.723360         0.0
# std           105.712813    209.216627            3.711984         0.0
# min          1000.000000      0.000000            0.000000         0.0
# 25%          1999.000000     70.000000            3.000000         0.0
# 50%          2003.000000    105.000000            6.000000         0.0
# 75%          2008.000000    150.000000            9.000000         0.0
# max          9999.000000  17700.000000           12.000000         0.0
#
#          postalCode
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# 1. seller  column
# 2. offerType column
# ---  most likely do not contain a unique date
# 3. Looks like  on each row in  column  num_photos the actual value is  0

# %%
print(autos['price'].dtype)
# Out:
# object

# %%
autos['price'] = autos['price'].str.replace('$','')
autos['price'] = autos['price'].str.replace(',','')
autos['price'] = autos['price'].str.strip()

# %%
autos['price'] = autos['price'].astype('int')

# %%
autos['odometer'] = autos['odometer'].str.replace('km','')
autos['odometer'] = autos['odometer'].str.replace(',','.')

# %%
autos['odometer'] = autos['odometer'].astype('float')

# %%
autos = autos.rename(columns={'odometer':'odometer_km'})

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos['odometer_km'].describe()
# Out:
# count    50000.000000
# mean       125.732700
# std         40.042212
# min          5.000000
# 25%        125.000000
# 50%        150.000000
# 75%        150.000000
# max        150.000000
# Name: odometer_km, dtype: float64

# %%
autos['price'].unique().shape
# Out:
# (2357,)

# %%
autos['odometer_km'].unique().shape
# Out:
# (13,)

# %%
p_c = autos['price'].value_counts().sort_index(ascending = True)

# %%
print(p_c)
# Out:
# price
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
#             ...
# 10000000       1
# 11111111       2
# 12345678       3
# 27322222       1
# 99999999       1
# Name: count, Length: 2357, dtype: int64

# %%
o_c = autos['odometer_km'].value_counts().sort_index(ascending = True)

print(o_c)
# Out:
# odometer_km
# 5.0        967
# 10.0       264
# 20.0       784
# 30.0       789
# 40.0       819
# 50.0      1027
# 60.0      1164
# 70.0      1230
# 80.0      1436
# 90.0      1757
# 100.0     2169
# 125.0     5170
# 150.0    32424
# Name: count, dtype: int64

# %%
autos = autos.drop(autos[autos["price"].between(10000000,99999999 )].index)

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos['date_crawled'].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# date_crawled
# 2016-03-05 14:06:30    0.00002
# 2016-03-05 14:06:40    0.00002
# 2016-03-05 14:07:04    0.00002
# 2016-03-05 14:07:08    0.00002
# 2016-03-05 14:07:21    0.00002
#                         ...
# 2016-04-07 14:30:09    0.00002
# 2016-04-07 14:30:26    0.00002
# 2016-04-07 14:36:44    0.00002
# 2016-04-07 14:36:55    0.00002
# 2016-04-07 14:36:56    0.00002
# Name: proportion, Length: 48206, dtype: float64

# %%
autos['last_seen'].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# last_seen
# 2016-03-05 14:45:46    0.00002
# 2016-03-05 14:46:02    0.00002
# 2016-03-05 14:49:34    0.00002
# 2016-03-05 15:16:11    0.00002
# 2016-03-05 15:16:47    0.00002
#                         ...
# 2016-04-07 14:58:44    0.00006
# 2016-04-07 14:58:45    0.00002
# 2016-04-07 14:58:46    0.00002
# 2016-04-07 14:58:48    0.00006
# 2016-04-07 14:58:50    0.00008
# Name: proportion, Length: 39477, dtype: float64

# %%
autos['ad_created'].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# ad_created
# 2015-06-11 00:00:00    0.000020
# 2015-08-10 00:00:00    0.000020
# 2015-09-09 00:00:00    0.000020
# 2015-11-10 00:00:00    0.000020
# 2015-12-05 00:00:00    0.000020
#                          ...
# 2016-04-03 00:00:00    0.038926
# 2016-04-04 00:00:00    0.036886
# 2016-04-05 00:00:00    0.011842
# 2016-04-06 00:00:00    0.003261
# 2016-04-07 00:00:00    0.001280
# Name: proportion, Length: 76, dtype: float64

# %% [markdown]
# Based on my observations, I can say that dates are quite unique, which is evident from the percentage values. And I think it's better when all dates are in the same digital format.

# %%
autos['registration_year'].describe()
# Out:
# count    49992.000000
# mean      2005.074552
# std        105.720930
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Here you can see that there is incorrect data, for example, the maximum or minimum values are clearly incorrect.

# %%
autos = autos[(autos['registration_year'] >= 1900) & (autos['registration_year'] <= 2026)]

# %%
autos['registration_year'].describe()
# Out:
# count    49968.000000
# mean      2003.367835
# std          7.690122
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2019.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# We have successfully removed incorrect maximum and minimum values and now see correct average and frequent values in the .describe() method.

# %%
display(autos)
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos['brand'].value_counts()
# Out:
# brand
# volkswagen        10681
# opel               5457
# bmw                5428
# mercedes_benz      4731
# audi               4283
# ford               3478
# renault            2404
# peugeot            1456
# fiat               1307
# seat                940
# skoda               785
# mazda               757
# nissan              754
# smart               701
# citroen             699
# toyota              617
# sonstige_autos      541
# hyundai             488
# volvo               456
# mini                424
# mitsubishi          404
# honda               399
# kia                 356
# alfa_romeo          329
# porsche             294
# suzuki              293
# chevrolet           283
# chrysler            181
# dacia               129
# daihatsu            128
# jeep                109
# subaru              108
# land_rover           99
# saab                 79
# daewoo               79
# jaguar               77
# trabant              77
# rover                69
# ...

# %%
top_20_brand_list = autos['brand'].value_counts().index[:20]

# %% [markdown]
# For further analysis, I selected the 20 most common brands from our dataset thanks to the value_counts() method.

# %%
brand_mean_price_dict = {}
brand_mean_km_dict = {}

# %%
for i in top_20_brand_list: 
    filteredbrand = autos[autos['brand']==i]
    avrg_price = filteredbrand['price'].mean()
    #print(avrg_price)
    brand_mean_price_dict[i] = int(avrg_price)
brand_mean_price_dict = dict(sorted(brand_mean_price_dict.items(),key=lambda x:x[1]))
brand_mean_price_dict
# Out:
# {'renault': 2351,
#  'fiat': 2697,
#  'opel': 2842,
#  'peugeot': 3010,
#  'smart': 3482,
#  'citroen': 3680,
#  'ford': 3913,
#  'mazda': 3962,
#  'seat': 4223,
#  'nissan': 4588,
#  'volvo': 4685,
#  'toyota': 5097,
#  'hyundai': 5316,
#  'volkswagen': 5345,
#  'skoda': 6313,
#  'bmw': 8254,
#  'mercedes_benz': 8380,
#  'audi': 8965,
#  'mini': 10392,
#  'sonstige_autos': 20154}

# %% [markdown]
# Based on the analysis, we can say that although Volkswagen has the most models, it still has a fairly average price on the market, which makes it affordable for the mid-range class.

# %%
bmp_series = pd.Series(brand_mean_price_dict )
print(bmp_series)
# Out:
# renault            2351
# fiat               2697
# opel               2842
# peugeot            3010
# smart              3482
# citroen            3680
# ford               3913
# mazda              3962
# seat               4223
# nissan             4588
# volvo              4685
# toyota             5097
# hyundai            5316
# volkswagen         5345
# skoda              6313
# bmw                8254
# mercedes_benz      8380
# audi               8965
# mini              10392
# sonstige_autos    20154
# dtype: int64

# %%
mean_price_df = pd.DataFrame(bmp_series, columns=['mean_price'])
mean_price_df
# Out:
#                 mean_price
# renault               2351
# fiat                  2697
# opel                  2842
# peugeot               3010
# smart                 3482
# citroen               3680
# ford                  3913
# mazda                 3962
# seat                  4223
# nissan                4588
# volvo                 4685
# toyota                5097
# hyundai               5316
# volkswagen            5345
# skoda                 6313
# bmw                   8254
# mercedes_benz         8380
# audi                  8965
# mini                 10392
# sonstige_autos       20154

# %%
for i in top_20_brand_list: 
    filteredbrand = autos[autos['brand']==i]
    avrg_km= filteredbrand['odometer_km'].mean()
    #print(avrg_price)
    brand_mean_km_dict[i] = int(avrg_km)
brand_mean_km_dict = dict(sorted(brand_mean_km_dict.items(),key=lambda x:x[1]))
brand_mean_km_dict
# Out:
# {'sonstige_autos': 87,
#  'mini': 89,
#  'smart': 100,
#  'hyundai': 106,
#  'skoda': 111,
#  'toyota': 115,
#  'fiat': 117,
#  'nissan': 118,
#  'citroen': 120,
#  'seat': 122,
#  'ford': 124,
#  'mazda': 125,
#  'peugeot': 127,
#  'renault': 128,
#  'volkswagen': 129,
#  'opel': 129,
#  'audi': 129,
#  'mercedes_benz': 130,
#  'bmw': 132,
#  'volvo': 138}

# %%
bm_km_series = pd.Series(brand_mean_km_dict )
mean_km_df = pd.DataFrame(bm_km_series, columns=['mean_km'])

# %%
mean_km_df
# Out:
#                 mean_km
# sonstige_autos       87
# mini                 89
# smart               100
# hyundai             106
# skoda               111
# toyota              115
# fiat                117
# nissan              118
# citroen             120
# seat                122
# ford                124
# mazda               125
# peugeot             127
# renault             128
# volkswagen          129
# opel                129
# audi                129
# mercedes_benz       130
# bmw                 132
# volvo               138

# %% [markdown]
# Based on the mileage analysis, we see that although Volkswagen has an average price, its average mileage is higher than that of cheaper analogues, for example, Fiat.

# %%
display(autos)
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos['date_crawled'] = autos['date_crawled'].str.replace("-","")

# %%
autos['name'].describe()
# Out:
# count           49968
# unique          38726
# top       Ford_Fiesta
# freq               78
# Name: name, dtype: object

# %%
top = autos['name'].describe().top

# %%
top_df = autos[autos['name'] == top].copy()

# %%
top_df
# Out:
#             date_crawled         name  seller offerType  price   abtest  \
# 1595   20160326 19:51:30  Ford_Fiesta  privat   Angebot   5500  control
# 2148   20160308 17:41:20  Ford_Fiesta  privat   Angebot    950  control
# 3562   20160307 15:48:09  Ford_Fiesta  privat   Angebot   1650  control
# 4276   20160329 10:57:11  Ford_Fiesta  privat   Angebot    600  control
# 4367   20160325 09:54:44  Ford_Fiesta  privat   Angebot   3200     test
# ...                  ...          ...     ...       ...    ...      ...
# 46197  20160327 21:54:17  Ford_Fiesta  privat   Angebot    700     test
# 47347  20160311 11:54:52  Ford_Fiesta  privat   Angebot    550  control
# 47587  20160317 12:37:22  Ford_Fiesta  privat   Angebot    275     test
# 48600  20160323 00:55:27  Ford_Fiesta  privat   Angebot   5000     test
# 49329  20160323 22:54:50  Ford_Fiesta  privat   Angebot    950     test
#
#       vehicleType  registration_year  gearbox  powerPS   model  odometer_km  \
# ...

# %% [markdown]
# The most popular value in the name column is Ford_Fiesta

# %%
top_df['unrepaired_damage'] = top_df['unrepaired_damage'].str.replace("ja","yes")

# %%
top_df['unrepaired_damage'] = top_df['unrepaired_damage'].str.replace("nein","no")

# %%
damage_ford_mean_price = top_df[top_df['unrepaired_damage'] == "yes"]['price'].mean()
damage_ford_mean_price
# Out:
# np.float64(1033.7777777777778)

# %%
no_damage_ford_mean_price = top_df[top_df['unrepaired_damage'] == "no"]['price'].mean()
no_damage_ford_mean_price
# Out:
# np.float64(1925.1666666666667)

# %%
difference_ford =  int(no_damage_ford_mean_price -damage_ford_mean_price)
difference_ford
# Out:
# 891
